#   inflating: Diseases/StripeCanker/IMG_4890.JPG
#   inflating: Diseases/StripeCanker/IMG_4891.JPG
#   inflating: Diseases/StripeCanker/IMG_E4799.JPG
#   inflating: Diseases/StripeCanker/IMG_E4800.JPG
#   inflating: Diseases/StripeCanker/IMG_E4801.JPG
#   inflating: Diseases/StripeCanker/IMG_E4802.JPG
#   inflating: Diseases/StripeCanker/IMG_E4803.JPG
#   inflating: Diseases/StripeCanker/IMG_E4816.JPG
#   inflating: Diseases/StripeCanker/IMG_E4818.JPG
#   inflating: Diseases/StripeCanker/IMG_E4820.JPG
#   inflating: Diseases/StripeCanker/IMG_E4875.JPG
#   inflating: Diseases/StripeCanker/IMG_E4876.JPG
#   inflating: Diseases/StripeCanker/IMG_E4877.JPG
#   inflating: Diseases/StripeCanker/IMG_E4878.JPG
#   inflating: Diseases/StripeCanker/IMG_E4879.JPG
#   inflating: Diseases/StripeCanker/IMG_E4880.JPG
#   inflating: Diseases/StripeCanker/IMG_E4881.JPG
#   inflating: Diseases/StripeCanker/IMG_E4882.JPG
#   inflating: Diseases/StripeCanker/IMG_E4883.JPG
#   inflating: Diseases/StripeCanker/IMG_E4884.JPG
#   inflating: Diseases/StripeCanker/IMG_E4885.JPG
#   inflating: Diseases/StripeCanker/IMG_E4886.JPG
#   inflating: Diseases/StripeCanker/IMG_E4887.JPG
#   inflating: Diseases/StripeCanker/IMG_E4888.JPG
#   inflating: Diseases/StripeCanker/IMG_E4889.JPG
#   inflating: Diseases/StripeCanker/IMG_E4890.JPG
#   inflating: Diseases/StripeCanker/IMG_E4891.JPG

# %%
import splitfolders
splitfolders.ratio('/content/Diseases', output="./", seed=1337, ratio=(.7, 0.2,0.1))
# Out:
# Copying files: 326 files [00:02, 147.11 files/s]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from PIL import Image

# %%
class CNNNet(nn.Module):

    def __init__(self, num_classes=2):
        super(CNNNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),#слой субдисктретизации (пулинг)
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 256, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(256, 512, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(512, 370, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(370, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Linear(4096, num_classes)
        )
    
    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %% [markdown]
# определение модели со сверточными слоями через класс CNNNet()
# это переопределение класса или что?

# %%
cnnnet = CNNNet()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Функция обучения
# По эпохам
# На вход модель model - по которой обучаемся
# train_loader, val_loader - обработанные кусочки датасета с batch, нормализацией и всей прочей фигней
# device - устройство для расчета (процессор или видеокарта)
# optimizer
#
# ---
#
# [Ссылка на учебник ИТМО](https://neerc.ifmo.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B3%D0%BB%D0%B0%D0%B2%D0%BD%D0%B0%D1%8F_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86%D0%B0)
# [Текст ссылки](https://vk.com/doc44301783_579615389?hash=hrHUm6WZfBPEYm6gEzF8y4CMjOJybMqCzET3OVA7THX)

# %%
def train(model, optimizer, loss_fn, train_loader, val_loader, epochs=20, device="cpu"):
    epoch_data= []
    training_loss_data = []
    valid_loss_data = []
    accuracy_data = []
    for epoch in range(1, epochs+1):
        training_loss = 0.0
        valid_loss = 0.0
        model.train()
        for batch in train_loader:
            optimizer.zero_grad()
            inputs, targets = batch
            inputs = inputs.to(device)
            targets = targets.to(device)
            output = model(inputs)
            loss = loss_fn(output, targets)
            loss.backward()
            optimizer.step()
            training_loss += loss.data.item() * inputs.size(0)
        training_loss /= len(train_loader.dataset)
        
        model.eval()
        num_correct = 0 
        num_examples = 0
        for batch in val_loader:
            inputs, targets = batch
            inputs = inputs.to(device)
            output = model(inputs)
            targets = targets.to(device)
            loss = loss_fn(output,targets) 
            valid_loss += loss.data.item() * inputs.size(0)
            correct = torch.eq(torch.max(F.softmax(output, dim=1), dim=1)[1],
                               targets)
            num_correct += torch.sum(correct).item()
            num_examples += correct.shape[0]
        valid_loss /= len(val_loader.dataset)

        print('Epoch: {}, Training Loss: {:.2f}, Validation Loss: {:.2f}, accuracy = {:.2f}'.format(epoch, training_loss,
        valid_loss, num_correct / num_examples))

        epoch_data.append(epoch)
        training_loss_data.append(training_loss)
        valid_loss_data.append(valid_loss)
        accuracy_data.append(num_correct / num_examples)
        
        fig, ax = plt.subplots(figsize=(8, 6))
        ax.set_title('Графики зависимостей', fontsize=16)
        ax.set_xlabel('Epoch', fontsize=14)
        ax.set_ylabel('Training Loss, Validation Loss, accuracy', fontsize=14)
        ax.grid(which='major', linewidth=1.2)
        ax.grid(which='minor', linestyle='--', color='gray', linewidth=0.5)
        
        ax.scatter(epoch_data, accuracy_data, c='red', label='accuracy')
        ax.plot(epoch_data, training_loss_data, c='yellow', label='Training Loss')
        ax.plot(epoch_data, valid_loss_data, c='green', label='Validation Loss')
        
        ax.legend()

        plt.show()

# %%
def check_image(path):
    try:
        im = Image.open(path)
        return True
    except:
        return False

img_transforms = transforms.Compose([
    transforms.Resize((64,64)),    
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
    ])
train_data_path = "./train/"
train_data = torchvision.datasets.ImageFolder(root=train_data_path,transform=img_transforms, is_valid_file=check_image)
val_data_path = "./val/"
val_data = torchvision.datasets.ImageFolder(root=val_data_path,transform=img_transforms, is_valid_file=check_image)
batch_size=64
train_data_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,shuffle=True)
val_data_loader  = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)

if torch.cuda.is_available():
    device = torch.device("cuda") 
else:
    device = torch.device("cpu")

# %%
cnnnet.to(device)
optimizer = optim.Adam(cnnnet.parameters(), lr=0.001)

# %%
train(cnnnet, optimizer,torch.nn.CrossEntropyLoss(), train_data_loader,val_data_loader, epochs=10, device=device)
# Out:
# Epoch: 1, Training Loss: 0.14, Validation Loss: 0.64, accuracy = 0.84
# Epoch: 2, Training Loss: 0.10, Validation Loss: 1.53, accuracy = 0.88
# Epoch: 3, Training Loss: 0.23, Validation Loss: 0.77, accuracy = 0.80
# Epoch: 4, Training Loss: 0.33, Validation Loss: 0.72, accuracy = 0.62
# Epoch: 5, Training Loss: 0.43, Validation Loss: 0.53, accuracy = 0.75
# Epoch: 6, Training Loss: 0.33, Validation Loss: 0.51, accuracy = 0.78
# Epoch: 7, Training Loss: 0.26, Validation Loss: 0.47, accuracy = 0.81
# Epoch: 8, Training Loss: 0.20, Validation Loss: 0.46, accuracy = 0.86
# Epoch: 9, Training Loss: 0.19, Validation Loss: 0.56, accuracy = 0.84
# Epoch: 10, Training Loss: 0.21, Validation Loss: 0.64, accuracy = 0.88
